# %% [markdown]
# #lab 15 ELISA

# %% [markdown]
# #Purpose:
# in this laboratory, the response of human kidneys to excessive concentrations of water and salt in body fluids will be demonstrated by analysis of the volume and salt concentration of urine. In addition, a urinalysis will be conducted to determine the specific gravity, pH, protein, glucose, ketone, bilirubin and blood content of normal urine.![IMG_4642.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #Procedure:
# 1) coat w/ antigen
# 2) Add 1 Ab (serum or plasma)
# 3) Wash
# 4) Add 2 Ab
# 5) Wash
# repeat the process.

# %% [markdown]
# #Discussion:
# Initially there was no reaction or change from the antigens, but after repeating the steps the reaction was more visible.

# %% [markdown]
# #Conclusion:
# In conclusion the this clearly showed how the residuals of antigens can stay behind even after being exposed to water.
